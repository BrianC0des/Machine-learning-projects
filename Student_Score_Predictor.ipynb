# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianC0des/Machine-learning-projects/blob/main/Student_Score_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Data Processing

# %%
#loading dataset to a pandas DataFrame
score_data = pd.read_csv('/content/large_student_scores_1000.csv')
label_encoder = LabelEncoder()
score_data["Pass/Fail"] = label_encoder.fit_transform(score_data["Pass/Fail"])

# %%
score_data.head()
# Out:
#    Student_ID  Score  Pass/Fail
# 0           1     23          0
# 1           2     25          0
# 2           3     88          1
# 3           4     59          1
# 4           5     40          0

# %%
# number of rows and columns
score_data.shape
# Out:
# (1000, 3)

# %%
score_data.describe()
# Out:
#         Student_ID        Score    Pass/Fail
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000    49.678000     0.504000
# std     288.819436    30.129057     0.500234
# min       1.000000     0.000000     0.000000
# 25%     250.750000    23.000000     0.000000
# 50%     500.500000    50.000000     1.000000
# 75%     750.250000    75.000000     1.000000
# max    1000.000000   100.000000     1.000000

# %%
score_data["Pass/Fail"].value_counts()
# Out:
# Pass/Fail
# 1    504
# 0    496
# Name: count, dtype: int64

# %% [markdown]
# Pass --> 1
#
# Fail --> 0

# %%
#separating data to labels
X = score_data.drop(columns='Pass/Fail', axis=1)
Y = score_data['Pass/Fail']

# %%
print(X)
print(Y)
# Out:
#      Student_ID  Score
# 0             1     23
# 1             2     25
# 2             3     88
# 3             4     59
# 4             5     40
# ..          ...    ...
# 995         996      2
# 996         997     32
# 997         998      5
# 998         999     49
# 999        1000      9
#
# [1000 rows x 2 columns]
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Pass/Fail, Length: 1000, dtype: int64

# %% [markdown]
# Training and Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# %%
print(X_train)
print(Y_train)
# Out:
#      Student_ID  Score
# 791         792     96
# 917         918      7
# 106         107     96
# 45           46     46
# 289         290     31
# ..          ...    ...
# 181         182     91
# 832         833     49
# 895         896     88
# 708         709     25
# 782         783     81
#
# [800 rows x 2 columns]
# 791    1
# 917    0
# 106    1
# 45     0
# 289    0
#       ..
# 181    1
# 832    0
# 895    1
# 708    0
# 782    1
# Name: Pass/Fail, Length: 800, dtype: int64

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model withn training data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaulation

# %%
#accuracy on the training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy: ", training_data_accuracy)
# Out:
# Accuracy:  1.0

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy: ", testing_data_accuracy)
# Out:
# Accuracy:  1.0

# %% [markdown]
# Predictive System

# %%
input_data = (10,88)

input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)
input_data_df = pd.DataFrame(input_data_reshaped, columns=["Student_ID", "Score"] )

prediction = model.predict(input_data_df)
print(predicition)

if prediction == 0:
  print("Failed")

else:
  print("Passed")
# Out:
# [0]
# Passed
